# %% [markdown]
# # Module 4 — Extraction de Caractéristiques NLP
#
# Ce module couvre :
# 1. Prétraitement textuel (tokenisation, stopwords anti-leakage, stemming/lemmatisation)
# 2. Vectorisation : BoW, TF-IDF, Word2Vec, FastText
# 3. Classification : Naive Bayes, Régression Logistique, LinearSVC, Random Forest
# 4. Bonus : Sentence Transformers multilingue (SBERT)
#
# **Split : 70 % train / 10 % val / 10 % test (stratifié)**

# %% [markdown]
# ## ⚙️ 0. Installations & Imports

# %%
# Installations (à exécuter une fois)
import subprocess, sys

packages = [
    'nltk', 'spacy', 'gensim', 'scikit-learn', 'pandas',
    'numpy', 'matplotlib', 'seaborn', 'fasttext-wheel'
]
for pkg in packages:
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', pkg], check=False)

print('Packages installés')
# Out:
# Packages installés

# %%
import os, re, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB, ComplementNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (classification_report, confusion_matrix,
                              accuracy_score, f1_score)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder

from gensim.models import Word2Vec
import gensim.downloader as api

warnings.filterwarnings('ignore')
os.makedirs('outputs', exist_ok=True)
SEED = 42

# Téléchargements NLTK
for resource in ['punkt', 'stopwords', 'wordnet', 'punkt_tab']:
    nltk.download(resource, quiet=True)

print('✅ Imports OK')
# Out:
# ✅ Imports OK

# %% [markdown]
# ## 📂 1. Chargement du Dataset

# %%
import os, numpy as np, pandas as pd  # guard — déjà importés en cellule 0

# ─────────────────────────────────────────────────────────────────
# Chargement : full_cleaned.csv (prétraité par Module 1)
#              + Rapport_Collecte depuis le CSV original
# ─────────────────────────────────────────────────────────────────

DATA_PATH     = 'outputs/full_cleaned.csv'       # produit par Module 1
ORIG_CSV_PATH = 'dataset_ProjetML_2026 (1).csv'  # CSV original  ← adapter si besoin
TEXT_COL      = 'Rapport_Collecte'               # colonne texte NLP
LABEL_COL     = 'Categorie'                      # colonne cible

# ── Chargement du fichier prétraité ──────────────────────────────
if not os.path.exists(DATA_PATH):
    raise FileNotFoundError(f"Fichier introuvable : {DATA_PATH} — exécuter Module 1 d'abord.")

df = pd.read_csv(DATA_PATH)
print(f'✅ full_cleaned.csv chargé  →  {df.shape}')

# ── Récupération de Rapport_Collecte (absente de full_cleaned) ───
if TEXT_COL not in df.columns:
    if not os.path.exists(ORIG_CSV_PATH):
        raise FileNotFoundError(
            f"CSV original introuvable : {ORIG_CSV_PATH}\n"
            f"Colonnes disponibles dans full_cleaned.csv : {list(df.columns)}"
        )
    df_orig = pd.read_csv(ORIG_CSV_PATH, sep=',', header=0)
    if TEXT_COL not in df_orig.columns:
        raise ValueError(f"Colonne '{TEXT_COL}' introuvable dans {ORIG_CSV_PATH}.\n"
                         f"Colonnes dispo : {list(df_orig.columns)}")

    # Aligner par position : Module 1 a fait dropna(Categorie) + reset_index
    df_orig_aligned = df_orig.dropna(subset=[LABEL_COL]).reset_index(drop=True)
    df[TEXT_COL] = df_orig_aligned[TEXT_COL].values[:len(df)]
    print(f'✅ {TEXT_COL} mergée depuis {ORIG_CSV_PATH}')
else:
    print(f'✅ {TEXT_COL} déjà présente dans full_cleaned.csv')

# ── Garder uniquement les colonnes utiles au NLP ─────────────────
n_avant = len(df)
df = df[[TEXT_COL, LABEL_COL]].dropna().reset_index(drop=True)
print(f'   Lignes retenues : {len(df)} / {n_avant}')
print(f'   Classes : {df[LABEL_COL].value_counts().to_dict()}')
df.head(5)
# Out:
# ✅ full_cleaned.csv chargé  →  (9986, 8)
# ✅ Rapport_Collecte déjà présente dans full_cleaned.csv
#    Lignes retenues : 9986 / 9986
#    Classes : {'Plastique': 2795, 'Verre': 2586, 'Papier': 2318, 'Métal': 2287}
#                                     Rapport_Collecte  Categorie
# 0  Lot de papier récupéré dans un site non rensei...     Papier
# 1  Lot plastique à l'Usine A. Volume 64.7 L, poid...  Plastique
# 2  Bris de verre ou contenants en provenance de l...      Verre
# 3  Feuilles et cartons collectés au Centre de Tri...     Papier
# 4  Déchet de type papier identifié à l'Usine B. V...     Papier

# %% [markdown]
# ## 🔤 2. Prétraitement Textuel

# %%
# ── Stopwords : français NLTK + domaine métier + anti-leakage ───
STOP_FR = set(stopwords.words('french'))

STOP_DOMAIN = {
    # ── Génériques domaine ────────────────────────────────────
    'utilisation', 'usage', 'haute', 'haut', 'bon', 'bonne',
    'grand', 'grande', 'type', 'produit', 'matériau', 'matériaux',
    'excellent', 'excellente', 'faible', 'élevé', 'élevée',
    'moyen', 'moyenne', 'application', 'applications',

    # ── 🚨 Labels directs (leakage principal) ────────────────
    'papier', 'papiers',
    'plastique', 'plastiques',
    'verre', 'verres',
    'métal', 'metal', 'métaux', 'metaux',
    'métallique', 'metallique', 'métalliques',
    'ferreux', 'ferraille', 'ferrailles',
    'carton', 'cartons',

    # ── 🚨 Mots quasi-exclusifs par classe (leakage indirect) ─
    # Métal
    'conductivité', 'conductivite', 'conducteur', 'conductrice', 'conducteurs',
    # Verre
    'transparent', 'transparente', 'transparence',
    'opaque', 'opacité', 'opacite',
    # Papier
    'cellulose', 'fibre', 'fibres', 'feuille', 'feuilles',
    # Plastique
    'polymère', 'polymere', 'polymères', 'resine', 'résine',

    # ── Mots de collecte non informatifs ─────────────────────
    'lot', 'lots', 'site', 'usine', 'provenance',
    'récupéré', 'recupere', 'collecte', 'collecté',
    'renseigné', 'renseigne', 'masse', 'poids', 'volume',
    'état', 'etat', 'aspect', 'trace', 'traces',
    'contamination', 'légère', 'legere',
}

ALL_STOPS = STOP_FR | STOP_DOMAIN

# ── Stemmer & Lemmatizer ──────────────────────────────────────
stemmer    = SnowballStemmer('french')
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    """Nettoyage de base : minuscules, suppression caractères spéciaux."""
    text = str(text).lower()
    text = re.sub(r'[^a-zàâäéèêëîïôùûüÿç\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def tokenize(text):
    """Tokenisation NLTK."""
    return word_tokenize(text, language='french')

def remove_stopwords(tokens):
    """Suppression des stopwords français + domaine."""
    return [t for t in tokens if t not in ALL_STOPS and len(t) > 2]

def stem_tokens(tokens):
    """Stemming SnowballStemmer."""
    return [stemmer.stem(t) for t in tokens]

def lemmatize_tokens(tokens):
    """Lemmatisation WordNet."""
    return [lemmatizer.lemmatize(t) for t in tokens]

def preprocess(text, method='stem'):
    """Pipeline complet : nettoyage → tokenisation → stopwords → stem/lemma."""
    tokens = tokenize(clean_text(text))
    tokens = remove_stopwords(tokens)
    if method == 'stem':
        tokens = stem_tokens(tokens)
    elif method == 'lemma':
        tokens = lemmatize_tokens(tokens)
    return ' '.join(tokens)

# ── Appliquer aux deux variantes ──────────────────────────────
df['text_stem']  = df[TEXT_COL].apply(lambda x: preprocess(x, method='stem'))
df['text_lemma'] = df[TEXT_COL].apply(lambda x: preprocess(x, method='lemma'))
df['tokens']     = df[TEXT_COL].apply(lambda x: remove_stopwords(tokenize(clean_text(x))))

# ── Vérification anti-leakage ─────────────────────────────────
leakage_words = ['papier', 'plastique', 'verre', 'métal', 'conductivité', 'opaque']
sample_stem = df['text_stem'].iloc[0]
found = [w for w in leakage_words if w in sample_stem]
if found:
    print(f'⚠️  Mots de leakage encore présents : {found}')
else:
    print('✅ Anti-leakage OK — aucun mot de label détecté')

print('\nExemple prétraitement :')
idx = 0
print(f'  Original : {df[TEXT_COL].iloc[idx]}')
print(f'  Stemming : {df["text_stem"].iloc[idx]}')
print(f'  Lemma    : {df["text_lemma"].iloc[idx]}')
# Out:
# Exemple prétraitement :
#   Original : Lot de papier récupéré dans un site non renseigné. Poids léger de 16.7 kg, volume moyen. Matériau souple, non conducteur, aspect très opaque. Bon état général.
#   Stemming : lot récuper sit non renseign poid leg volum soupl non conducteur aspect tres opaqu état général
#   Lemma    : lot récupéré site non renseigné poids léger volume souple non conducteur aspect très opaque état général

# %% [markdown]
# ## ✂️ 3. Split Train / Validation / Test

# %%
le = LabelEncoder()
y  = le.fit_transform(df[LABEL_COL])

X_stem  = df['text_stem'].values
X_lemma = df['text_lemma'].values
tokens  = df['tokens'].tolist()

# ── Split 70 / 10 / 10 avec stratification ───────────────────
# Étape 1 : train (70 %) vs tmp (30 %)
X_train_s, X_tmp_s, y_train, y_tmp = train_test_split(
    X_stem, y, test_size=0.30, stratify=y, random_state=SEED
)
# Étape 2 : val (10 %) et test (10 %) → 50/50 de 30 %
X_val_s, X_test_s, y_val, y_test = train_test_split(
    X_tmp_s, y_tmp, test_size=0.50, stratify=y_tmp, random_state=SEED
)

# Même découpage pour textes lemmatisés
X_train_l, X_tmp_l, _, _ = train_test_split(
    X_lemma, y, test_size=0.30, stratify=y, random_state=SEED
)
X_val_l, X_test_l, _, _ = train_test_split(
    X_tmp_l, y_tmp, test_size=0.50, stratify=y_tmp, random_state=SEED
)

# Même découpage pour tokens (Word2Vec / FastText)
tokens_train, tokens_tmp, _, _ = train_test_split(
    tokens, y, test_size=0.30, stratify=y, random_state=SEED
)
tokens_val, tokens_test, _, _ = train_test_split(
    tokens_tmp, y_tmp, test_size=0.50, stratify=y_tmp, random_state=SEED
)

n_total = len(y)
print(f'Total  : {n_total}')
print(f'Train  : {len(X_train_s):>5}  ({len(X_train_s)/n_total*100:.1f} %)')
print(f'Val    : {len(X_val_s):>5}  ({len(X_val_s)/n_total*100:.1f} %)')
print(f'Test   : {len(X_test_s):>5}  ({len(X_test_s)/n_total*100:.1f} %)')
print(f'Classes : {list(le.classes_)}')

# Vérification stratification
for name, y_part in [('Train', y_train), ('Val', y_val), ('Test', y_test)]:
    counts = pd.Series(y_part).value_counts(normalize=True).sort_index()
    print(f'  {name} distribution : {dict(zip(le.classes_, counts.round(3).values))}')
# Out:
# Total  : 9986
# Train  :  6990  (70.0 %)
# Val    :  1498  (15.0 %)
# Test   :  1498  (15.0 %)
# Classes : ['Métal', 'Papier', 'Plastique', 'Verre']

# %% [markdown]
# ## 📦 4. Vectorisation
#
# ### 4.1 Bag of Words (BoW)

# %%
bow_vec = CountVectorizer(max_features=5000, ngram_range=(1,1))
X_bow_train = bow_vec.fit_transform(X_train_s)
X_bow_val   = bow_vec.transform(X_val_s)
X_bow_test  = bow_vec.transform(X_test_s)

print(f'BoW  → train: {X_bow_train.shape}  |  val: {X_bow_val.shape}  |  test: {X_bow_test.shape}')
print(f'Vocabulaire : {len(bow_vec.vocabulary_)} termes')
# Out:
# BoW  → train: (6990, 107)  |  val: (1498, 107)  |  test: (1498, 107)
# Vocabulaire : 107 termes

# %% [markdown]
# ### 4.2 TF-IDF (uni + bigrammes)

# %%
tfidf_vec = TfidfVectorizer(
    max_features=8000,
    ngram_range=(1, 2),     # unigrammes + bigrammes
    sublinear_tf=True,      # log(1+tf)
    min_df=2
)
X_tfidf_train = tfidf_vec.fit_transform(X_train_s)
X_tfidf_val   = tfidf_vec.transform(X_val_s)
X_tfidf_test  = tfidf_vec.transform(X_test_s)

print(f'TF-IDF → train: {X_tfidf_train.shape}  |  val: {X_tfidf_val.shape}  |  test: {X_tfidf_test.shape}')

# Top termes TF-IDF par classe
feature_names = np.array(tfidf_vec.get_feature_names_out())
print('\nTop 5 termes TF-IDF par classe :')
for cls_idx, cls_name in enumerate(le.classes_):
    mask   = y_train == cls_idx
    scores = X_tfidf_train[mask].mean(axis=0).A1
    top5   = feature_names[np.argsort(scores)[-5:][::-1]]
    print(f'  {cls_name:12s}: {list(top5)}')
# Out:
# TF-IDF → train: (6990, 547)  |  val: (1498, 547)  |  test: (1498, 547)
#
# Top 5 termes TF-IDF par classe :
#   Métal       : ['conduct', 'conduct rigid', 'rigid', 'valeur marchand', 'valeur']
#   Papier      : ['soupl', 'opaqu', 'tres opaqu', 'leg', 'tres']
#   Plastique   : ['sem', 'rigid', 'sem rigid', 'rigid non', 'non']
#   Verre       : ['rigid', 'lourd', 'tres rigid', 'extrêm', 'extrêm rigid']

# %% [markdown]
# ### 4.3 Word2Vec (embeddings sémantiques)

# %%
# Entraîner Word2Vec sur le corpus d'entraînement
w2v_model = Word2Vec(
    sentences=tokens_train,
    vector_size=100,
    window=5,
    min_count=1,
    workers=4,
    sg=1,          # Skip-gram
    seed=SEED,
    epochs=50
)

def text_to_w2v(tokens_list, model):
    """Moyenne des vecteurs Word2Vec pour chaque document."""
    vectors = []
    for tokens in tokens_list:
        vecs = [model.wv[t] for t in tokens if t in model.wv]
        vectors.append(np.mean(vecs, axis=0) if vecs else np.zeros(model.vector_size))
    return np.array(vectors)

X_w2v_train = text_to_w2v(tokens_train, w2v_model)
X_w2v_val   = text_to_w2v(tokens_val,   w2v_model)
X_w2v_test  = text_to_w2v(tokens_test,  w2v_model)

print(f'Word2Vec → train: {X_w2v_train.shape}  |  val: {X_w2v_val.shape}  |  test: {X_w2v_test.shape}')

# Mots les plus proches (test)
try:
    sample_word = tokens_train[0][0] if tokens_train[0] else 'metal'
    similar = w2v_model.wv.most_similar(sample_word, topn=5)
    print(f'\nMots proches de "{sample_word}" :')
    for word, score in similar:
        print(f'  {word:20s} sim={score:.3f}')
except Exception as e:
    print(f'Pas de mot similaire : {e}')
# Out:
# Word2Vec → train: (6990, 100)  |  val: (1498, 100)  |  test: (1498, 100)
#
# Mots proches de "déchet" :
#   texture              sim=0.393
#   très                 sim=0.347
#   importante           sim=0.344
#   identifié            sim=0.332
#   mesurée              sim=0.295

# %% [markdown]
# ### 4.4 FastText (robustesse aux OOV et fautes)

# %%
try:
    import fasttext
    FASTTEXT_AVAILABLE = True
except ImportError:
    FASTTEXT_AVAILABLE = False
    print('FastText non disponible — utilisation de Gensim FastText')

# ── Gensim FastText (toujours disponible) ────────────────────
from gensim.models import FastText as GensimFastText

ft_model = GensimFastText(
    sentences=tokens_train,
    vector_size=100,
    window=5,
    min_count=1,
    workers=4,
    sg=1,
    seed=SEED,
    epochs=50
)

def text_to_ft(tokens_list, model):
    """Moyenne des vecteurs FastText (gère les OOV via sous-mots)."""
    vectors = []
    for tokens in tokens_list:
        vecs = [model.wv[t] for t in tokens]  # FastText gère OOV nativement
        vectors.append(np.mean(vecs, axis=0) if vecs else np.zeros(model.vector_size))
    return np.array(vectors)

X_ft_train = text_to_ft(tokens_train, ft_model)
X_ft_val   = text_to_ft(tokens_val,   ft_model)
X_ft_test  = text_to_ft(tokens_test,  ft_model)

print(f'FastText → train: {X_ft_train.shape}  |  val: {X_ft_val.shape}  |  test: {X_ft_test.shape}')

# Test robustesse OOV (mot avec faute de frappe)
test_oov = 'metalique'  # faute intentionnelle
vec_oov = ft_model.wv[test_oov]
print(f'\nFastText gère les OOV — vecteur "{test_oov}" : dim={vec_oov.shape}, non-nul={np.any(vec_oov)}')
# Out:
# FastText → train: (6990, 100)  |  val: (1498, 100)  |  test: (1498, 100)
#
# FastText gère les OOV — vecteur "metalique" : dim=(100,), non-nul=True

# %% [markdown]
# ## 🤖 5. Classification
#
# ### 5.1 Fonctions utilitaires

# %%
results = []   # stockage global des résultats

def evaluate(name, clf, X_tr, X_val, X_te, y_tr, y_val, y_te, classes):
    """Entraîne sur train, sélectionne sur val, évalue sur test."""
    clf.fit(X_tr, y_tr)
    # ── Validation (sélection de modèle) ──
    y_val_pred = clf.predict(X_val)
    acc_val = accuracy_score(y_val, y_val_pred)
    f1_val  = f1_score(y_val, y_val_pred, average='weighted')
    # ── Test (évaluation finale) ──
    y_te_pred = clf.predict(X_te)
    acc_te = accuracy_score(y_te, y_te_pred)
    f1_te  = f1_score(y_te, y_te_pred, average='weighted')
    results.append({
        'Modèle'        : name,
        'Acc Val'       : acc_val,
        'F1 Val'        : f1_val,
        'Acc Test'      : acc_te,
        'F1 Test'       : f1_te,
    })
    print(f'{name:40s}  Val Acc={acc_val:.4f} F1={f1_val:.4f}  |  Test Acc={acc_te:.4f} F1={f1_te:.4f}')
    return clf, y_te_pred

def plot_confusion(y_te, y_pred, classes, title):
    cm = confusion_matrix(y_te, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=classes, yticklabels=classes)
    plt.title(title)
    plt.ylabel('Réel')
    plt.xlabel('Prédit')
    plt.tight_layout()
    plt.show()

CLASSES = list(le.classes_)
print('Fonctions utilitaires prêtes.')
# Out:
# Fonctions utilitaires prêtes.

# %% [markdown]
# ### 5.2 BoW + Classificateurs

# %%
print('=== BoW — Baseline ===')
evaluate('BoW + Naive Bayes Multinomial',
         MultinomialNB(),
         X_bow_train, X_bow_val, X_bow_test, y_train, y_val, y_test, CLASSES)

evaluate('BoW + Logistic Regression',
         LogisticRegression(max_iter=1000, C=1.0, random_state=SEED),
         X_bow_train, X_bow_val, X_bow_test, y_train, y_val, y_test, CLASSES)

evaluate('BoW + LinearSVC',
         LinearSVC(C=1.0, max_iter=2000, random_state=SEED),
         X_bow_train, X_bow_val, X_bow_test, y_train, y_val, y_test, CLASSES)

evaluate('BoW + Random Forest',
         RandomForestClassifier(n_estimators=200, random_state=SEED),
         X_bow_train, X_bow_val, X_bow_test, y_train, y_val, y_test, CLASSES)
# Out:
# === BoW — Baseline ===
# BoW + Naive Bayes Multinomial             Val Acc=0.9773 F1=0.9772  |  Test Acc=0.9713 F1=0.9710
# BoW + Logistic Regression                 Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
# BoW + LinearSVC                           Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
# BoW + Random Forest                       Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
# (RandomForestClassifier(n_estimators=200, random_state=42),
#  array([0, 0, 0, ..., 0, 0, 0]))

# %% [markdown]
# ### 5.3 TF-IDF + Classificateurs

# %%
print('=== TF-IDF (uni+bigrammes) — Référence ===')

evaluate('TF-IDF + Naive Bayes Complement',
         ComplementNB(),
         X_tfidf_train, X_tfidf_val, X_tfidf_test, y_train, y_val, y_test, CLASSES)

evaluate('TF-IDF + Logistic Regression',
         LogisticRegression(max_iter=1000, C=5.0, random_state=SEED),
         X_tfidf_train, X_tfidf_val, X_tfidf_test, y_train, y_val, y_test, CLASSES)

best_clf, best_pred = evaluate('TF-IDF + LinearSVC',
         LinearSVC(C=1.0, max_iter=2000, random_state=SEED),
         X_tfidf_train, X_tfidf_val, X_tfidf_test, y_train, y_val, y_test, CLASSES)

evaluate('TF-IDF + Random Forest',
         RandomForestClassifier(n_estimators=200, random_state=SEED),
         X_tfidf_train, X_tfidf_val, X_tfidf_test, y_train, y_val, y_test, CLASSES)

print('\nRapport détaillé — Test set (TF-IDF + LinearSVC) :')
print(classification_report(y_test, best_pred, target_names=CLASSES))
# Out:
# === TF-IDF (uni+bigrammes) — Référence ===
# TF-IDF + Naive Bayes Complement           Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
# TF-IDF + Logistic Regression              Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
# TF-IDF + LinearSVC                        Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
# TF-IDF + Random Forest                    Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
#
# Rapport détaillé — Test set (TF-IDF + LinearSVC) :
#               precision    recall  f1-score   support
#
#        Métal       1.00      1.00      1.00       343
#       Papier       1.00      1.00      1.00       348
#    Plastique       1.00      1.00      1.00       419
#        Verre       1.00      1.00      1.00       388
#
#     accuracy                           1.00      1498
#    macro avg       1.00      1.00      1.00      1498
# weighted avg       1.00      1.00      1.00      1498

# %% [markdown]
# ### 5.4 Word2Vec + Classificateurs

# %%
print('=== Word2Vec (embeddings) ===')

evaluate('Word2Vec + Logistic Regression',
         LogisticRegression(max_iter=1000, C=1.0, random_state=SEED),
         X_w2v_train, X_w2v_val, X_w2v_test, y_train, y_val, y_test, CLASSES)

evaluate('Word2Vec + LinearSVC',
         LinearSVC(C=1.0, max_iter=2000, random_state=SEED),
         X_w2v_train, X_w2v_val, X_w2v_test, y_train, y_val, y_test, CLASSES)

evaluate('Word2Vec + Random Forest',
         RandomForestClassifier(n_estimators=200, random_state=SEED),
         X_w2v_train, X_w2v_val, X_w2v_test, y_train, y_val, y_test, CLASSES)
# Out:
# === Word2Vec (embeddings) ===
# Word2Vec + Logistic Regression            Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
# Word2Vec + LinearSVC                      Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
# Word2Vec + Random Forest                  Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
# (RandomForestClassifier(n_estimators=200, random_state=42),
#  array([0, 0, 0, ..., 0, 0, 0]))

# %% [markdown]
# ### 5.5 FastText + Classificateurs

# %%
print('=== FastText (robuste OOV) ===')

evaluate('FastText + Logistic Regression',
         LogisticRegression(max_iter=1000, C=1.0, random_state=SEED),
         X_ft_train, X_ft_val, X_ft_test, y_train, y_val, y_test, CLASSES)

evaluate('FastText + LinearSVC',
         LinearSVC(C=1.0, max_iter=2000, random_state=SEED),
         X_ft_train, X_ft_val, X_ft_test, y_train, y_val, y_test, CLASSES)

evaluate('FastText + Random Forest',
         RandomForestClassifier(n_estimators=200, random_state=SEED),
         X_ft_train, X_ft_val, X_ft_test, y_train, y_val, y_test, CLASSES)
# Out:
# === FastText (robuste OOV) ===
# FastText + Logistic Regression            Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
# FastText + LinearSVC                      Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
# FastText + Random Forest                  Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
# (RandomForestClassifier(n_estimators=200, random_state=42),
#  array([0, 0, 0, ..., 0, 0, 0]))

# %% [markdown]
# ## 🌟 6. Bonus — CamemBERT (Sentence Transformers)

# %%
pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (2.7.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.57.6)
# Requirement already satisfied: tqdm in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (2.2.2+cpu)
# Requirement already satisfied: numpy in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.15.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (0.36.2)
# Requirement already satisfied: Pillow in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (12.0.0)
# Requirement already satisfied: filelock in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (3.29.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2026.4.4)
# Requirement already satisfied: requests in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2026.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hp\appdata\roaming\python\python310\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.15.0)
# Requirement already satisfied: sympy in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python310\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers<5.0.0,>=4.34.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers<5.0.0,>=4.34.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers<5.0.0,>=4.34.0->sentence-transformers) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers<5.0.0,>=4.34.0->sentence-transformers) (2026.1.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
try:
    from sentence_transformers import SentenceTransformer
    ST_AVAILABLE = True
except ImportError:
    import subprocess, sys
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'sentence-transformers'], check=False)
    try:
        from sentence_transformers import SentenceTransformer
        ST_AVAILABLE = True
    except ImportError:
        ST_AVAILABLE = False
        print('sentence-transformers non installé — section bonus ignorée.')

if ST_AVAILABLE:
    print('Chargement du modèle CamemBERT (paraphrase-multilingual-mpnet-base-v2)...')
    print('⚠️  Premier chargement : téléchargement ~400 Mo — patience.')

    sbert = SentenceTransformer('paraphrase-multilingual-mpnet-base-v2')

    # ── Indices cohérents avec le split 70/15/15 ──────────────
    idx_all = np.arange(len(df))
    train_idx, tmp_idx, _, y_tmp_s = train_test_split(
        idx_all, y, test_size=0.30, stratify=y, random_state=SEED
    )
    val_idx, test_idx, _, _ = train_test_split(
        tmp_idx, y_tmp_s, test_size=0.50, stratify=y_tmp_s, random_state=SEED
    )

    print('Encodage train...')
    X_sbert_train = sbert.encode(df[TEXT_COL].iloc[train_idx].tolist(),
                                  batch_size=32, show_progress_bar=True)
    print('Encodage val...')
    X_sbert_val   = sbert.encode(df[TEXT_COL].iloc[val_idx].tolist(),
                                  batch_size=32, show_progress_bar=True)
    print('Encodage test...')
    X_sbert_test  = sbert.encode(df[TEXT_COL].iloc[test_idx].tolist(),
                                  batch_size=32, show_progress_bar=True)

    y_tr_sbert  = y[train_idx]
    y_val_sbert = y[val_idx]
    y_te_sbert  = y[test_idx]

    print(f'\nSBERT embeddings → train: {X_sbert_train.shape}  |  val: {X_sbert_val.shape}  |  test: {X_sbert_test.shape}')

    print('=== CamemBERT / Sentence Transformers ===')
    evaluate('SBERT + Logistic Regression',
             LogisticRegression(max_iter=1000, C=1.0, random_state=SEED),
             X_sbert_train, X_sbert_val, X_sbert_test,
             y_tr_sbert, y_val_sbert, y_te_sbert, CLASSES)

    evaluate('SBERT + LinearSVC',
             LinearSVC(C=1.0, max_iter=2000, random_state=SEED),
             X_sbert_train, X_sbert_val, X_sbert_test,
             y_tr_sbert, y_val_sbert, y_te_sbert, CLASSES)
else:
    print('Bonus SBERT ignoré.')
# Out:
# Chargement du modèle CamemBERT (paraphrase-multilingual-mpnet-base-v2)...
# ⚠️  Premier chargement : téléchargement ~400 Mo — patience.
# Encodage train...
# Batches: 100%|██████████| 219/219 [04:49<00:00,  1.32s/it]
# Encodage val...
# Batches: 100%|██████████| 47/47 [00:59<00:00,  1.27s/it]
# Encodage test...
# Batches: 100%|██████████| 47/47 [00:59<00:00,  1.26s/it]
# SBERT embeddings → train: (6990, 768)  |  val: (1498, 768)  |  test: (1498, 768)
# === CamemBERT / Sentence Transformers ===
# SBERT + Logistic Regression               Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000
# SBERT + LinearSVC                         Val Acc=1.0000 F1=1.0000  |  Test Acc=1.0000 F1=1.0000

# %% [markdown]
# ## 📊 7. Comparaison Finale

# %%
df_res = pd.DataFrame(results).sort_values('F1 Test', ascending=False)
print('=== RÉSUMÉ COMPARATIF ===')
display(df_res.round(4).reset_index(drop=True))

# ── Graphique comparatif (F1 Val vs F1 Test) ─────────────────
fig, ax = plt.subplots(figsize=(13, max(5, len(df_res)*0.45)))

y_pos = np.arange(len(df_res))
bars_test = ax.barh(y_pos - 0.2, df_res['F1 Test'], height=0.35,
                    color='steelblue', label='F1 Test')
bars_val  = ax.barh(y_pos + 0.2, df_res['F1 Val'],  height=0.35,
                    color='darkorange', alpha=0.7, label='F1 Val')

for bar, acc in zip(bars_test, df_res['Acc Test']):
    ax.text(bar.get_width() + 0.005, bar.get_y() + bar.get_height()/2,
            f'{acc:.3f}', va='center', fontsize=7)

ax.set_yticks(y_pos)
ax.set_yticklabels(df_res['Modèle'], fontsize=9)
ax.set_xlabel('F1-score (weighted)')
ax.set_title('Comparaison des modèles NLP — Val vs Test (split 70/10/10)')
ax.set_xlim(0, 1.18)
ax.axvline(x=df_res['F1 Test'].max(), color='red',
           linestyle='--', alpha=0.6, label='Meilleur F1 Test')
ax.legend()
ax.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.savefig('outputs/nlp_comparison.png', dpi=120)
plt.show()

best_model = df_res.iloc[0]
print(f'\n🏆 Meilleur modèle : {best_model["Modèle"]}')
print(f'   Acc Val   : {best_model["Acc Val"]:.4f}   F1 Val  : {best_model["F1 Val"]:.4f}')
print(f'   Acc Test  : {best_model["Acc Test"]:.4f}   F1 Test : {best_model["F1 Test"]:.4f}')
# Out:
# === RÉSUMÉ COMPARATIF ===
#                              Modèle  Acc Val  F1 Val  Acc Test  F1 Test
# 0         BoW + Logistic Regression   1.0000  1.0000    1.0000    1.000
# 1                   BoW + LinearSVC   1.0000  1.0000    1.0000    1.000
# 2               BoW + Random Forest   1.0000  1.0000    1.0000    1.000
# 3   TF-IDF + Naive Bayes Complement   1.0000  1.0000    1.0000    1.000
# 4      TF-IDF + Logistic Regression   1.0000  1.0000    1.0000    1.000
# 5                TF-IDF + LinearSVC   1.0000  1.0000    1.0000    1.000
# 6            TF-IDF + Random Forest   1.0000  1.0000    1.0000    1.000
# 7    Word2Vec + Logistic Regression   1.0000  1.0000    1.0000    1.000
# 8              Word2Vec + LinearSVC   1.0000  1.0000    1.0000    1.000
# 9          Word2Vec + Random Forest   1.0000  1.0000    1.0000    1.000
# 10   FastText + Logistic Regression   1.0000  1.0000    1.0000    1.000
# 11             FastText + LinearSVC   1.0000  1.0000    1.0000    1.000
# 12         FastText + Random Forest   1.0000  1.0000    1.0000    1.000
# 13      SBERT + Logistic Regression   1.0000  1.0000    1.0000    1.000
# 14                SBERT + LinearSVC   1.0000  1.0000    1.0000    1.000
# 15    BoW + Naive Bayes Multinomial   0.9773  0.9772    0.9713    0.971
# 🏆 Meilleur modèle : BoW + Logistic Regression
#    Acc Val   : 1.0000   F1 Val  : 1.0000
#    Acc Test  : 1.0000   F1 Test : 1.0000

# %% [markdown]
# ## 🗂️ 8. Matrice de Confusion — Meilleur Modèle

# %%
# TF-IDF + LinearSVC — évaluation finale sur le test set
final_clf = LinearSVC(C=1.0, max_iter=2000, random_state=SEED)
final_clf.fit(X_tfidf_train, y_train)
y_final_pred = final_clf.predict(X_tfidf_test)

print('Rapport de classification — Test set (TF-IDF + LinearSVC) :')
print(classification_report(y_test, y_final_pred, target_names=CLASSES))

plot_confusion(y_test, y_final_pred, CLASSES, 'Matrice de confusion — TF-IDF + LinearSVC (Test set)')
# Out:
# Rapport de classification — Test set (TF-IDF + LinearSVC) :
#               precision    recall  f1-score   support
#
#        Métal       1.00      1.00      1.00       343
#       Papier       1.00      1.00      1.00       348
#    Plastique       1.00      1.00      1.00       419
#        Verre       1.00      1.00      1.00       388
#
#     accuracy                           1.00      1498
#    macro avg       1.00      1.00      1.00      1498
# weighted avg       1.00      1.00      1.00      1498

# %% [markdown]
# ## 💾 9. Sauvegarde

# %%
import pickle

# ── Sauvegarder le meilleur pipeline (entraîné sur TRAIN uniquement) ─
best_pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(max_features=8000, ngram_range=(1,2),
                               sublinear_tf=True, min_df=2)),
    ('clf',   LinearSVC(C=1.0, max_iter=2000, random_state=SEED))
])
# ⚠️  On entraîne sur X_train_s uniquement — le test reste unseen
best_pipeline.fit(X_train_s, y_train)

with open('outputs/nlp_best_pipeline.pkl', 'wb') as f:
    pickle.dump({'pipeline': best_pipeline, 'label_encoder': le}, f)

# Sauvegarder les résultats
df_res.to_csv('outputs/nlp_results.csv', index=False)

print('✅ Sauvegardés :')
print('   outputs/nlp_best_pipeline.pkl')
print('   outputs/nlp_results.csv')
print('   outputs/nlp_comparison.png')

# ── Test du pipeline sauvegardé ──────────────────────────────
test_texts = [
    'Plaque résistante à la corrosion, densité élevée, rigidité maximale',
    'Surface souple et légère, non conductrice, aspect mat',
    'Matériau dense, rigidité élevée, transparence partielle',
    'Texture fibreuse, souple, non conducteur, aspect très mat',
]
test_processed = [preprocess(t, method='stem') for t in test_texts]
predictions    = le.inverse_transform(best_pipeline.predict(test_processed))
print('\nTest du pipeline (sans mots de label) :')
for text, pred in zip(test_texts, predictions):
    print(f'  [{pred:12s}]  {text[:60]}')
# Out:
# ✅ Sauvegardés :
#    outputs/nlp_best_pipeline.pkl
#    outputs/nlp_results.csv
#    outputs/nlp_comparison.png
#
# Test du pipeline :
#   [Métal       ]  Plaque en acier inoxydable très résistante à la corrosi...
#   [Papier      ]  Panneau de bois massif pour cuisine et ameublement...
#   [Papier      ]  Plastique recyclé haute densité léger et flexible...

# %%
# ── Fin du Module 4 ──────────────────────────────────────────
print('\n✅ Module 4 terminé.')
print(f'   Meilleur modèle  : {df_res.iloc[0]["Modèle"]}')
print(f'   F1 Test          : {df_res.iloc[0]["F1 Test"]:.4f}')
print(f'   Fichiers outputs : nlp_best_pipeline.pkl, nlp_results.csv, nlp_comparison.png')
# Out:
# === VÉRIFICATION DU DATASET ===
#
# 1. Taille totale : 9986
#    Train : 6990, Val : 1498, Test : 1498
#
# 2. Distribution des classes (test set) :
# Counter({2: 419, 3: 388, 1: 348, 0: 343})
#
# 3. Exemple de texte brut vs catégorie :
#
#    Catégorie : Papier
#    Texte    : Lot de papier récupéré dans un site non renseigné. Poids léger de 16.7 kg, volume moyen. Matériau souple, non conducteur, aspect très opaque. Bon état
#
#    Catégorie : Plastique
#    Texte    : Lot plastique à l'Usine A. Volume 64.7 L, poids 47.3 kg. Aspect indéterminée, rigidité moyenne. Aucune trace de métal.
#
#    Catégorie : Verre
#    Texte    : Bris de verre ou contenants en provenance de l'Usine B. Masse non mesuré kg. Matériau dense, rigidité élevée, transparence partielle. Légère contamina
#
# 4. Longueur moyenne des textes :
# count    9986.000000
# mean       21.024134
# std         2.389871
# min        15.000000
# 25%        19.000000
# 50%        21.000000
# 75%        23.000000
# max        28.000000
# Name: Rapport_Collecte, dtype: float64
#
# 5. Mots les plus fréquents par classe (risque de leakage) :
#    Papier: [('de', 3267), ('papier', 1842), ('kg.', 1819), ('opaque.', 1722), ('matériau', 1493)]
#    Plastique: [('de', 2848), ('poids', 1773), ('volume', 1768), ('non', 1753), ('plastique', 1695)]
#    Verre: [('de', 2634), ('verre', 2586), ('volume', 1622), ('poids', 1598), ('non', 1563)]
#    Métal: [('de', 1891), ('conductivité', 1830), ('poids', 1477), ('kg.', 1374), ('volume', 1032)]
